# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
from from_result import *

path = "../data"
save_path = "../plots"

# %% [markdown]
# Mass scaling

# %%
scalings = [1 + 0.1 * i for i in range(-5, 6)]
xlabel = "Mass scaling factor"

xpi0, xpi10, xpi11, bsigma0, bsigma10, bsigma11 = get_reaction_rate_dependence("mass_scaling", scalings, is_mass_factor_parameter=True)

fig, ax = plot_reaction_rate_dependence_0(xlabel, scalings, xpi0, bsigma0)
fig, ax = plot_reaction_rate_dependence_1(xlabel, scalings, xpi10, xpi11, bsigma10, bsigma11)
fig, ax = plot_ratio_dependence(xlabel, scalings, xpi0, xpi10, xpi11, bsigma0, bsigma10, bsigma11, False)

# %% [markdown]
# Rotational constant scaling - small changes

# %%
scalings = [1 + 0.1 * i for i in range(-5, 6)]
xlabel = "Rotational constant scaling factor"

xpi0, xpi10, xpi11, bsigma0, bsigma10, bsigma11 = get_reaction_rate_dependence("rot_scaling", scalings)

fig, ax = plot_reaction_rate_dependence_0(xlabel, scalings, xpi0, bsigma0)
fig, ax = plot_reaction_rate_dependence_1(xlabel, scalings, xpi10, xpi11, bsigma10, bsigma11)
fig, ax = plot_ratio_dependence(xlabel, scalings, xpi0, xpi10, xpi11, bsigma0, bsigma10, bsigma11, False)

# %% [markdown]
# Rotational constant scaling - large changes

# %%
scalings = [1.0] + [10 * i for i in range(1, 11)]
xlabel = "Rotational constant scaling factor"

xpi0, xpi10, xpi11, bsigma0, bsigma10, bsigma11 = get_reaction_rate_dependence("rot_scaling", scalings)

fig, ax = plot_reaction_rate_dependence_0(xlabel, scalings, xpi0, bsigma0)
fig, ax = plot_reaction_rate_dependence_1(xlabel, scalings, xpi10, xpi11, bsigma10, bsigma11)
fig, ax = plot_ratio_dependence(xlabel, scalings, xpi0, xpi10, xpi11, bsigma0, bsigma10, bsigma11, False)

# %% [markdown]
# potential scaling

# %%
scalings = [1 + 0.1 * i for i in range(-5, 6)]
xlabel = "Potential scaling factor"

xpi0, xpi10, xpi11, bsigma0, bsigma10, bsigma11 = get_reaction_rate_dependence("pot_scaling", scalings)

fig, ax = plot_reaction_rate_dependence_0(xlabel, scalings, xpi0, bsigma0)
fig, ax = plot_reaction_rate_dependence_1(xlabel, scalings, xpi10, xpi11, bsigma10, bsigma11)
fig, ax = plot_ratio_dependence(xlabel, scalings, xpi0, xpi10, xpi11, bsigma0, bsigma10, bsigma11)

# %% [markdown]
# XPi gamma scaling

# %%
scalings = [1 + 0.1 * i for i in range(-5, 6)]
xlabel = "Xpi gamma scaling factor"

xpi0, xpi10, xpi11, bsigma0, bsigma10, bsigma11 = get_reaction_rate_dependence("xpi_scaling", scalings)

fig, ax = plot_reaction_rate_dependence_0(xlabel, scalings, xpi0, bsigma0)
fig, ax = plot_reaction_rate_dependence_1(xlabel, scalings, xpi10, xpi11, bsigma10, bsigma11)
fig, ax = plot_ratio_dependence(xlabel, scalings, xpi0, xpi10, xpi11, bsigma0, bsigma10, bsigma11)

# %% [markdown]
# BSigma gamma scaling

# %%
scalings = [1 + 0.1 * i for i in range(-5, 6)]
xlabel = "BSigma gamma scaling factor"

xpi0, xpi10, xpi11, bsigma0, bsigma10, bsigma11 = get_reaction_rate_dependence("bsigma_scaling", scalings)

fig, ax = plot_reaction_rate_dependence_0(xlabel, scalings, xpi0, bsigma0)
fig, ax = plot_reaction_rate_dependence_1(xlabel, scalings, xpi10, xpi11, bsigma10, bsigma11)
fig, ax = plot_ratio_dependence(xlabel, scalings, xpi0, xpi10, xpi11, bsigma0, bsigma10, bsigma11)

# %% [markdown]
# APi gamma scaling

# %%
scalings = [1 + 0.1 * i for i in range(-5, 6)]
xlabel = "APi gamma scaling factor"

xpi0, xpi10, xpi11, bsigma0, bsigma10, bsigma11 = get_reaction_rate_dependence("api_scaling", scalings)

fig, ax = plot_reaction_rate_dependence_0(xlabel, scalings, xpi0, bsigma0)
fig, ax = plot_reaction_rate_dependence_1(xlabel, scalings, xpi10, xpi11, bsigma10, bsigma11)
fig, ax = plot_ratio_dependence(xlabel, scalings, xpi0, xpi10, xpi11, bsigma0, bsigma10, bsigma11)

# %% [markdown]
# Gamma stripes

# %%
scalings = list(map(lambda x: f"{x-20}_{x}", range(20, 200, 20)))
centers = list(map(lambda x: (x - 20 + x)/2, range(20, 200, 20)))
xlabel = "center of masking stripe [deg]"

xpi0, xpi10, xpi11, bsigma0, bsigma10, bsigma11 = get_reaction_rate_dependence("gammas_scaling_stripe", scalings, identity=None)

fig, ax = plot_reaction_rate_dependence_0(xlabel, centers, xpi0, bsigma0)
fig, ax = plot_reaction_rate_dependence_1(xlabel, centers, xpi10, xpi11, bsigma10, bsigma11)
fig, ax = plot_ratio_dependence(xlabel, centers, xpi0, xpi10, xpi11, bsigma0, bsigma10, bsigma11)
