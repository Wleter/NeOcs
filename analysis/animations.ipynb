# %%
from matplotlib import animation
from from_wave import *

save_path = "../plots"

# %% [markdown]
# Standard animation

# %%
anim = wave_animation("standard")
anim.save(f'{save_path}/standard_wave_animation.gif', writer="pillow", fps=30)

# %%
anim = angular_animation("standard")
anim.save(f'{save_path}/standard_angular_animation.gif', writer="pillow", fps=30)

# %%
fig, ax = loss_plot("standard")

# %% [markdown]
# Small rotational constant

# %%
anim = wave_animation("small_rot_scaling")
anim.save(f'{save_path}/small_rot_wave_animation.gif', writer="pillow", fps=30)

# %%
anim = angular_animation("small_rot_scaling")
anim.save(f'{save_path}/small_rot_angular_animation.gif', writer="pillow", fps=30)

# %% [markdown]
# Large rotational constant

# %%
anim = wave_animation("big_rot_scaling")
anim.save(f'{save_path}/big_rot_wave_animation.gif', writer="pillow", fps=30)

# %%
anim = angular_animation("big_rot_scaling")
anim.save(f'{save_path}/big_rot_angular_animation.gif', writer="pillow", fps=30)

# %%
anim = wave_animation("standard_0_0")
anim.save(f'{save_path}/standard_0_0_wave_animation.gif', writer="pillow", fps=30)

anim = wave_animation("standard_1_0")
anim.save(f'{save_path}/standard_1_0_wave_animation.gif', writer="pillow", fps=30)

anim = wave_animation("standard_1_1")
anim.save(f'{save_path}/standard_1_1_wave_animation.gif', writer="pillow", fps=30)

# %%
anim = angular_animation("standard_0_0")
anim.save(f'{save_path}/standard_0_0_angular_animation.gif', writer="pillow", fps=30)

anim = angular_animation("standard_1_0")
anim.save(f'{save_path}/standard_1_0_angular_animation.gif', writer="pillow", fps=30)

anim = angular_animation("standard_1_1")
anim.save(f'{save_path}/standard_1_1_angular_animation.gif', writer="pillow", fps=30)

# %%
anim = polar_animation("standard_0_0")
anim.save(f'{save_path}/standard_0_0_polar_animation.gif', writer="pillow", fps=30)

anim = polar_animation("standard_1_0")
anim.save(f'{save_path}/standard_1_0_polar_animation.gif', writer="pillow", fps=30)

anim = polar_animation("standard_1_1")
anim.save(f'{save_path}/standard_1_1_polar_animation.gif', writer="pillow", fps=30)

# %%
fig, ax = alignements("standard", [0, 1, 3, 5])
ax.lines[0].set_linewidth(5)
ax.lines[1].set_linewidth(2)
ax.legend()
fig.savefig(f"{save_path}/alignment_standard.pdf")

pass
