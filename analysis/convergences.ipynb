# %%
import sys
sys.path.append("../")

from utility.reaction_rate_calc import *
from utility.plotting import *

PATH = "../data/"
SAVE_PATH = "../plots/"

# %%
time_steps = np.array([5., 10., 20., 50., 100.])
dependencies = ReactionDependence(time_steps, PATH, Ionization.Penning)

fig, ax = dependencies.plot_j_0(lambda e: f"time_step_{e}_0_0.dat")
dependencies.ionization_type = Ionization.Dissociative
fig, ax = dependencies.plot_j_0(lambda e: f"time_step_{e}_0_0.dat", (fig, ax))
ax.set_xlabel("Time step [a.u.]")
ax.set_xscale("log")
ax.set_xticks(time_steps)
ax.set_xticklabels(time_steps)

dependencies.ionization_type = Ionization.Penning
fig, ax = dependencies.plot_j_1(lambda e, j, omega: f"time_step_{e}_{j}_{omega}.dat")
dependencies.ionization_type = Ionization.Dissociative
fig, ax = dependencies.plot_j_1(lambda e, j, omega: f"time_step_{e}_{j}_{omega}.dat", (fig, ax))
ax.set_xlabel("Time step [a.u.]")
ax.set_xscale("log")
ax.set_xticks(time_steps)
ax.set_xticklabels(time_steps)

dependencies.ionization_type = Ionization.Penning
fig, ax = dependencies.plot_ratios(lambda e, j, omega: f"time_step_{e}_{j}_{omega}.dat")
dependencies.ionization_type = Ionization.Dissociative
fig, ax = dependencies.plot_ratios(lambda e, j, omega: f"time_step_{e}_{j}_{omega}.dat", (fig, ax))
ax.set_xlabel("Time step [a.u.]")
ax.set_xscale("log")
ax.set_xticks(time_steps)
ax.set_xticklabels(time_steps);

# %%
r_sizes = np.array([128, 256, 512, 1024, 2048, 4096])
dependencies = ReactionDependence(r_sizes, PATH, Ionization.Penning)

fig, ax = dependencies.plot_j_0(lambda e: f"radial_scaling_{e}_0_0.dat")
dependencies.ionization_type = Ionization.Dissociative
fig, ax = dependencies.plot_j_0(lambda e: f"radial_scaling_{e}_0_0.dat", (fig, ax))
ax.set_xlabel(r"$r_\text{no}$")
ax.set_xscale("log")
ax.set_xticks(r_sizes)
ax.set_xticklabels(r_sizes)

dependencies.ionization_type = Ionization.Penning
fig, ax = dependencies.plot_j_1(lambda e, j, omega: f"radial_scaling_{e}_{j}_{omega}.dat")
dependencies.ionization_type = Ionization.Dissociative
fig, ax = dependencies.plot_j_1(lambda e, j, omega: f"radial_scaling_{e}_{j}_{omega}.dat", (fig, ax))
ax.set_xlabel(r"$r_\text{no}$")
ax.set_xscale("log")
ax.set_xticks(r_sizes)
ax.set_xticklabels(r_sizes)

dependencies.ionization_type = Ionization.Penning
fig, ax = dependencies.plot_ratios(lambda e, j, omega: f"radial_scaling_{e}_{j}_{omega}.dat")
dependencies.ionization_type = Ionization.Dissociative
fig, ax = dependencies.plot_ratios(lambda e, j, omega: f"radial_scaling_{e}_{j}_{omega}.dat", (fig, ax))
ax.set_xlabel(r"$r_\text{no}$")
ax.set_xscale("log")
ax.set_xticks(r_sizes)
ax.set_xticklabels(r_sizes);

# %%
polar_sizes = np.array([32, 64, 128, 256, 512])
dependencies = ReactionDependence(polar_sizes, PATH, Ionization.Penning)

fig, ax = dependencies.plot_j_0(lambda e: f"polar_scaling_{e}_0_0.dat")
dependencies.ionization_type = Ionization.Dissociative
fig, ax = dependencies.plot_j_0(lambda e: f"polar_scaling_{e}_0_0.dat", (fig, ax))
ax.set_xlabel(r"$\theta_\text{no}$")
ax.set_xscale("log")
ax.set_xticks(polar_sizes)
ax.set_xticklabels(polar_sizes)

dependencies.ionization_type = Ionization.Penning
fig, ax = dependencies.plot_j_1(lambda e, j, omega: f"polar_scaling_{e}_{j}_{omega}.dat")
dependencies.ionization_type = Ionization.Dissociative
fig, ax = dependencies.plot_j_1(lambda e, j, omega: f"polar_scaling_{e}_{j}_{omega}.dat", (fig, ax))
ax.set_xlabel(r"$\theta_\text{no}$")
ax.set_xscale("log")
ax.set_xticks(polar_sizes)
ax.set_xticklabels(polar_sizes)

dependencies.ionization_type = Ionization.Penning
fig, ax = dependencies.plot_ratios(lambda e, j, omega: f"polar_scaling_{e}_{j}_{omega}.dat")
dependencies.ionization_type = Ionization.Dissociative
fig, ax = dependencies.plot_ratios(lambda e, j, omega: f"polar_scaling_{e}_{j}_{omega}.dat", (fig, ax))
ax.set_xlabel(r"$\theta_\text{no}$")
ax.set_xscale("log")
ax.set_xticks(polar_sizes)
ax.set_xticklabels(polar_sizes);

# %%
widths = np.array([0.1, 0.3, 0.6, 1, 2, 4])
dependencies = ReactionDependence(widths, PATH, Ionization.Penning)

fig, ax = dependencies.plot_j_0(lambda e: f"width_scaling_{e:g}_0_0.dat")
dependencies.ionization_type = Ionization.Dissociative
fig, ax = dependencies.plot_j_0(lambda e: f"width_scaling_{e:g}_0_0.dat", (fig, ax))
ax.set_xlabel(r"$\sigma_r$")
ax.set_xscale("log")
ax.set_xticks(widths)
ax.set_xticklabels(widths)

dependencies.ionization_type = Ionization.Penning
fig, ax = dependencies.plot_j_1(lambda e, j, omega: f"width_scaling_{e:g}_{j}_{omega}.dat")
dependencies.ionization_type = Ionization.Dissociative
fig, ax = dependencies.plot_j_1(lambda e, j, omega: f"width_scaling_{e:g}_{j}_{omega}.dat", (fig, ax))
ax.set_xlabel(r"$\sigma_r$")
ax.set_xscale("log")
ax.set_xticks(widths)
ax.set_xticklabels(widths)

dependencies.ionization_type = Ionization.Penning
fig, ax = dependencies.plot_ratios(lambda e, j, omega: f"width_scaling_{e:g}_{j}_{omega}.dat")
dependencies.ionization_type = Ionization.Dissociative
fig, ax = dependencies.plot_ratios(lambda e, j, omega: f"width_scaling_{e:g}_{j}_{omega}.dat", (fig, ax))
ax.set_xlabel(r"$\sigma_r$")
ax.set_xscale("log")
ax.set_xticks(widths)
ax.set_xticklabels(widths);

# %%
time_steps = np.array([50., 100., 200., 400., 800., 1600.])
dependencies = ReactionDependence(time_steps, PATH, Ionization.Penning, 
                                  unchanged_filename_prefix = "coriolis_losses_omega_max_2", unchanged_value = 50.)

fig, ax = dependencies.plot_j_0(lambda e: f"coriolis_time_step_{e}_0_0.dat")
dependencies.ionization_type = Ionization.Dissociative
fig, ax = dependencies.plot_j_0(lambda e: f"coriolis_time_step_{e}_0_0.dat", (fig, ax))
ax.set_xlabel("Time step [a.u.]")
ax.set_xscale("log")
ax.set_xticks(time_steps)
ax.set_xticklabels(time_steps)

dependencies.ionization_type = Ionization.Penning
fig, ax = dependencies.plot_j_1(lambda e, j, omega: f"coriolis_time_step_{e}_{j}_{omega}.dat")
dependencies.ionization_type = Ionization.Dissociative
fig, ax = dependencies.plot_j_1(lambda e, j, omega: f"coriolis_time_step_{e}_{j}_{omega}.dat", (fig, ax))
ax.set_xlabel("Time step [a.u.]")
ax.set_xscale("log")
ax.set_xticks(time_steps)
ax.set_xticklabels(time_steps)

dependencies.ionization_type = Ionization.Penning
fig, ax = dependencies.plot_ratios(lambda e, j, omega: f"coriolis_time_step_{e}_{j}_{omega}.dat")
dependencies.ionization_type = Ionization.Dissociative
fig, ax = dependencies.plot_ratios(lambda e, j, omega: f"coriolis_time_step_{e}_{j}_{omega}.dat", (fig, ax))
ax.set_xlabel("Time step [a.u.]")
ax.set_xscale("log")
ax.set_xticks(time_steps)
ax.set_xticklabels(time_steps);
