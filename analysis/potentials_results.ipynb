# %%
from from_wave import *

save_path = "../plots"
js = [0, 1, 5]

# %%
name = "isotropic"
fig, ax = show_potential(name)
fig.savefig(f"{save_path}/{name}_potential.pdf")
fig, ax, ax2 = alignments_with_distance(name, js)
ax.set_ylim(0, 1)
ax.legend()
fig.savefig(f"{save_path}/{name}_alignment.pdf")

# %%
name = "factor_1_0"
fig, ax = show_potential(name)
fig.savefig(f"{save_path}/{name}_potential.pdf")
fig, ax, ax2 = alignments_with_distance(name, js)
ax.set_ylim(0, 1)
ax.legend()
fig.savefig(f"{save_path}/{name}_alignment.pdf")

# %%
name = "factor_0_1"
fig, ax = show_potential(name)
fig.savefig(f"{save_path}/{name}_potential.pdf")
fig, ax, ax2 = alignments_with_distance(name, js)
ax.set_ylim(0, 1)
ax.legend()
fig.savefig(f"{save_path}/{name}_alignment.pdf")

# %%
name = "sin2_1_0.1"
fig, ax = show_potential(name)
fig.savefig(f"{save_path}/{name}_potential.pdf")
fig, ax, ax2 = alignments_with_distance(name, js)
ax.set_ylim(0, 1)
ax.legend()
fig.savefig(f"{save_path}/{name}_alignment.pdf")

# %%
name = "cos2_1_0.1"
fig, ax = show_potential(name)
fig.savefig(f"{save_path}/{name}_potential.pdf")
fig, ax, ax2 = alignments_with_distance(name, js)
ax.set_ylim(0, 1)
ax.legend()
fig.savefig(f"{save_path}/{name}_alignment.pdf")

# %%
name = "sin2_1_cos2_0.1"
fig, ax = show_potential(name)
fig.savefig(f"{save_path}/{name}_potential.pdf")
fig, ax, ax2 = alignments_with_distance(name, js)
ax.set_ylim(0, 1)
ax.legend()
fig.savefig(f"{save_path}/{name}_alignment.pdf")

# %%
name = "cos2_1_sin2_0.1"
fig, ax = show_potential(name)
fig.savefig(f"{save_path}/{name}_potential.pdf")
fig, ax, ax2 = alignments_with_distance(name, js)
ax.set_ylim(0, 1)
ax.legend()
fig.savefig(f"{save_path}/{name}_alignment.pdf")

# %%
name = "cos2_1_cos_0.2"
fig, ax = show_potential(name)
fig.savefig(f"{save_path}/{name}_potential.pdf")
fig, ax, ax2 = alignments_with_distance(name, js)
ax.set_ylim(0, 1)
ax.legend()
fig.savefig(f"{save_path}/{name}_alignment.pdf")

# %%
name = "sin2_1_cos_0.2"
fig, ax = show_potential(name)
fig.savefig(f"{save_path}/{name}_potential.pdf")
fig, ax, ax2 = alignments_with_distance(name, js)
ax.set_ylim(0, 1)
ax.legend()
fig.savefig(f"{save_path}/{name}_alignment.pdf")

# %%
name = "shift_cos2_0.1"
fig, ax = show_potential(name)
fig.savefig(f"{save_path}/{name}_potential.pdf")
fig, ax, ax2 = alignments_with_distance(name, js)
ax.set_ylim(0, 1)
ax.legend()
fig.savefig(f"{save_path}/{name}_alignment.pdf")

# %%
name = "shift_sin2_0.1"
fig, ax = show_potential(name)
fig.savefig(f"{save_path}/{name}_potential.pdf")
fig, ax, ax2 = alignments_with_distance(name, js)
ax.set_ylim(0, 1)
ax.legend()
fig.savefig(f"{save_path}/{name}_alignment.pdf")

# %%
name = "shift_cos_0.2"
fig, ax = show_potential(name)
fig.savefig(f"{save_path}/{name}_potential.pdf")
fig, ax, ax2 = alignments_with_distance(name, js)
ax.set_ylim(0, 1)
ax.legend()
fig.savefig(f"{save_path}/{name}_alignment.pdf")

# %%
name = "factor_cos_0.5"
fig, ax = show_potential(name)
fig.savefig(f"{save_path}/{name}_potential.pdf")
fig, ax, ax2 = alignments_with_distance(name, js)
ax.set_ylim(0, 1)
ax.legend()
fig.savefig(f"{save_path}/{name}_alignment.pdf")

# %%
name = "cos_0.5_shift_cos2_0.1"
fig, ax = show_potential(name)
fig.savefig(f"{save_path}/{name}_potential.pdf")
fig, ax, ax2 = alignments_with_distance(name, js)
ax.set_ylim(0, 1)
ax.legend()
fig.savefig(f"{save_path}/{name}_alignment.pdf")

# %%
name = "cos_0.5_shift_sin2_0.1"
fig, ax = show_potential(name)
fig.savefig(f"{save_path}/{name}_potential.pdf")
fig, ax, ax2 = alignments_with_distance(name, js)
ax.set_ylim(0, 1)
ax.legend()
fig.savefig(f"{save_path}/{name}_alignment.pdf")

# %%
name = "cos_0.5_shift_cos_0.2"
fig, ax = show_potential(name)
fig.savefig(f"{save_path}/{name}_potential.pdf")
fig, ax, ax2 = alignments_with_distance(name, js)
ax.set_ylim(0, 1)
ax.legend()
fig.savefig(f"{save_path}/{name}_alignment.pdf")

# %%
name = "cos_0.5_shift_cos_-0.2"
fig, ax = show_potential(name)
fig.savefig(f"{save_path}/{name}_potential.pdf")
fig, ax, ax2 = alignments_with_distance(name, js)
ax.set_ylim(0, 1)
ax.legend()
fig.savefig(f"{save_path}/{name}_alignment.pdf")

# %%
for scaling in [0.01, 0.1, 0.5, 2, 5, 10]:
    fig, ax = show_potential(f"cos2_1_scaled_{scaling}")
    fig, ax, ax2 = alignments_with_distance(f"cos2_1_scaled_{scaling}", js)
    ax.set_ylim(0, 1)
    ax.legend()
