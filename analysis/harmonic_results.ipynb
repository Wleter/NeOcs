# %%
import sys
sys.path.append("../")

from utility.animations import *
from utility.plotting import *

PATH = "../data"
SAVE_PATH = "../plots"

animator = Animator(PATH, "harmonic_iso", SAVE_PATH, "harmonic_iso")

# %%
animator.file_prefix = "harmonic_iso"
animator.save_prefix = "harmonic_iso"

animator.wave_2d_animation()
animator.distance_animation()
animator.angular_animation()
animator.polar_animation()
# Out:
# saved animation as ../plots/harmonic_iso_wave_animation.gif
# saved animation as ../plots/harmonic_iso_distance_animation.gif
# saved animation as ../plots/harmonic_iso_angular_animation.gif
# saved animation as ../plots/harmonic_iso_polar_animation.gif

# %%
animator.save_prefix = "harmonic_aniso"
animator.file_prefix = "harmonic_aniso"

animator.wave_2d_animation()
animator.distance_animation()
animator.angular_animation()
animator.polar_animation()
# Out:
# saved animation as ../plots/harmonic_aniso_wave_animation.gif
# saved animation as ../plots/harmonic_aniso_distance_animation.gif
# saved animation as ../plots/harmonic_aniso_angular_animation.gif
# saved animation as ../plots/harmonic_aniso_polar_animation.gif

# %%
animator.save_prefix = "harmonic_iso_coriolis"
animator.file_prefix = "harmonic_iso_coriolis"

animator.distance_animation()
animator.angular_animation()
animator.polar_animation()
animator.omega_animation()
# Out:
# saved animation as ../plots/harmonic_iso_coriolis_distance_animation.gif
# saved animation as ../plots/harmonic_iso_coriolis_angular_animation.gif
# saved animation as ../plots/harmonic_iso_coriolis_polar_animation.gif
# saved animation as ../plots/harmonic_iso_coriolis_omega_animation.gif

# %%
animator.save_prefix = "harmonic_aniso_coriolis"
animator.file_prefix = "harmonic_aniso_coriolis"

animator.distance_animation()
animator.angular_animation()
animator.polar_animation()
animator.omega_animation()
# Out:
# saved animation as ../plots/harmonic_aniso_coriolis_distance_animation.gif
# saved animation as ../plots/harmonic_aniso_coriolis_angular_animation.gif
# saved animation as ../plots/harmonic_aniso_coriolis_polar_animation.gif
# saved animation as ../plots/harmonic_aniso_coriolis_omega_animation.gif

# %%
last_state = LastState(PATH, "harmonic_iso")

fig, ax = last_state.wave_2d()
fig.savefig(f"{SAVE_PATH}/harmonic_iso_wave.pdf", bbox_inches = "tight")
fig, ax = last_state.distance()
fig.savefig(f"{SAVE_PATH}/harmonic_iso_distance.pdf", bbox_inches = "tight")
fig, ax = last_state.angular()
fig.savefig(f"{SAVE_PATH}/harmonic_iso_angular.pdf", bbox_inches = "tight")
fig, ax = last_state.polar()
fig.savefig(f"{SAVE_PATH}/harmonic_iso_polar.pdf", bbox_inches = "tight");

# %%
last_state = LastState(PATH, "harmonic_iso_coriolis")

fig, ax = last_state.distance()
fig.savefig(f"{SAVE_PATH}/harmonic_iso_coriolis_distance.pdf", bbox_inches = "tight")
fig, ax = last_state.angular()
fig.savefig(f"{SAVE_PATH}/harmonic_iso_coriolis_angular.pdf", bbox_inches = "tight")
fig, ax = last_state.polar()
fig.savefig(f"{SAVE_PATH}/harmonic_iso_coriolis_polar.pdf", bbox_inches = "tight")
fig, ax = last_state.omega()
fig.savefig(f"{SAVE_PATH}/harmonic_iso_coriolis_omega.pdf", bbox_inches = "tight");
